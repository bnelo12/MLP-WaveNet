# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mel_spect = np.load('../data_processed/1-feats.npy')
wav = np.load('../data_processed/1-wave.npy')

# %%
plt.imshow(mel_spect.T, origin='lower')

# %%
plt.plot(wav)
