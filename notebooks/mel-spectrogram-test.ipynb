# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile

# %%
mel_spect = np.load('../data_preprocessed/eval/2395-feats.npy')
wav = np.load('../data_preprocessed/eval/2395-wave.npy')

# %%
plt.imshow(mel_spect.T, origin='lower', aspect='auto')

# %%
plt.plot(wav)

# %%
chords = np.load('/home/c/Documents/claireNet/ClaireNet/data_preprocessed_eval/2-feats.npy')

# %%
f = plt.imshow(chords, origin='lower', aspect='auto')
plt.xlabel('Time Step ($t$)')
plt.ylabel('Note ($h_t$)')
plt.title('Note Representation of a 30 Second Music Clip')

f.figure.savefig('Sample2.pdf')
